# %% [markdown]
# ## Imports

# %%
import sys
import os
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.max_colwidth', 400)

import canalyst_candas.candas as cd
from canalyst_candas.configuration.config import Config

config_info = {
  "canalyst_api_key": "",
   "s3_access_key_id": "",
  "s3_secret_key": "",
  "fred_key": "",
  "default_dir": "",
  "mds_host": "",
  "wp_host": ""
}

config = Config(config=config_info)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# A configuration file has been created for you in
# /Users/jedgore/canalyst/keys.json.
# /var/folders/bx/l8mvwb5n4vl9y62rmlthg3y80000gn/T/ipykernel_50022/558792348.py:31: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
cd.help()
# Out:
# Canalyst Candas help
# Please go to https://pypi.org/project/canalyst-candas/#description for installation help
# For support, please contact jed.gore@canalyst.com
# For an API KEY please go to https://app.canalyst.com/u/settings/api-tokens
# For an Excel model download:get_excel_model(ticker, config)

# %% [markdown]
# ## Instantiate a search object and search in a list of tickers

# %%
canalyst_search = cd.Search(config)

# %%
df = canalyst_search.search_time_series(ticker='',
                        sector="",
                     time_series_name='ukraine')
df
# Out:
# Building search index...
# No.of.unique tickers:  8
# No.of.unique time series:  16
#           ticker                                    time_series_description  \
# 130334    YUM US                      Ukraine restaurants, # of restaurants
# 131345    YUM US                  Ukraine KFC restaurants, # of restaurants
# 131113    YUM US              Ukraine KFC F&L restaurants, # of restaurants
# 130945    YUM US                  Ukraine F&L restaurants, # of restaurants
# 351076   YNDX US       Operating losses resulting from sanctions in Ukraine
# 351097   YNDX US            Add: losses resulting from sanctions in Ukraine
# 77416      PM US                         Ukraine Total Cigarette Market, bn
# 77434      PM US                                    Ukraine Market Share, %
# 1054716    MT US                                        Ukraine revenue, mm
# 766235    IRM US                      Gain on Russia and Ukraine Divestment
# 766293    IRM US                      Gain on Russia and Ukraine Divestment
# 685553    HLF US             Ukraine New Preferred Members, 000s of members
# 884404    ERJ US         Embraer 190 - Dnipro avia (Ukraine) Firm Orders, #
# 884406    ERJ US  Embraer 190 - Dnipro avia (Ukraine) Firm Order Backlog, #
# 884405    ERJ US          Embraer 190 - Dnipro avia (Ukraine) Deliveries, #
# 536387    AMS SM                          Ukraine employees, # of employees
#
#                                                           time_series_name  \
# 130334                               z_PV0XAZ0182_MO_OS_Ukrainerestaurants
# 131345                            z_PV0XAZ0182_MO_OS_UkraineKFCrestaurants
# 131113                          z_PV0XAZ0182_MO_OS_UkraineKFCFLrestaurants
# 130945                             z_PV0XAZ0182_MO_OS_UkraineFLrestaurants
# 351076   z_UYDBUY0107_MO_AN_operatinglossesresultingfromsanctionsinukraine
# 351097         z_UYDBUY0107_MO_AN_addlossesresultingfromsanctionsinukraine
# 77416                       z_LPNBZH0187_MO_OS_ukrainetotalcigarettemarket
# 77434                                z_LPNBZH0187_MO_OS_ukrainemarketshare
# 1054716                                  z_A8NPYA0158_MO_OS_Ukrainerevenue
# 766235               z_68GJOU0144_MO_CCFS_GainonRussiaandUkraineDivestment
# 766293                z_68GJOU0144_MO_CFS_GainonRussiaandUkraineDivestment
# 685553                       z_9YOTGA0170_MO_OS_UkraineNewPreferredMembers
# 884404            z_HODOVT0193_MO_OS_Embraer190DniproaviaUkraineFirmOrders
# 884406      z_HODOVT0193_MO_OS_Embraer190DniproaviaUkraineFirmOrderBacklog
# 884405            z_HODOVT0193_MO_OS_Embraer190DniproaviaUkraineDeliveries
# 536387                                 z_E5EM5T0130_MO_OS_Ukraineemployees
#
#          is_driver  \
# 130334       False
# 131345       False
# 131113       False
# 130945       False
# 351076       False
# 351097       False
# 77416        False
# 77434        False
# 1054716      False
# 766235       False
# 766293       False
# 685553       False
# 884404       False
# 884406       False
# 884405       False
# 536387       False
#
#                                                                                                category  \
# 130334                                                                Consolidated Restaurant Breakdown
# 131345                                                                         KFC Restaurant Breakdown
# 131113                                                                         KFC Restaurant Breakdown
# 130945                                                                Consolidated Restaurant Breakdown
# 351076                                                                     Adjusted Numbers As Reported
# 351097                                                                     Adjusted Numbers As Reported
# 77416                                               Key Metrics - Key Market Size and Market Share (PR)
# 77434                                               Key Metrics - Key Market Size and Market Share (PR)
# 1054716                                Segmented Results - Geographic Revenue Breakdown (Annual Report)
# 766235                                                                   Cumulative Cash Flow Statement
# 766293                                                                              Cash Flow Statement
# 685553                                                        Key Metrics - New Members (Supplementary)
# 884404   Key Metrics - Embraer 190 Orders and Deliveries by Customer (Country) - (Deliveries & Backlog)
# 884406   Key Metrics - Embraer 190 Orders and Deliveries by Customer (Country) - (Deliveries & Backlog)
# 884405   Key Metrics - Embraer 190 Orders and Deliveries by Customer (Country) - (Deliveries & Backlog)
# 536387                                                         Key Metrics - Employee Distribution (FS)
#
#                                                                              Path  \
# 130334   US Companies/Consumer Discretionary/Restaurants/Quick Service Restaurant
# 131345   US Companies/Consumer Discretionary/Restaurants/Quick Service Restaurant
# 131113   US Companies/Consumer Discretionary/Restaurants/Quick Service Restaurant
# 130945   US Companies/Consumer Discretionary/Restaurants/Quick Service Restaurant
# 351076           US Companies/Communication Services/Interactive Media & Services
# 351097           US Companies/Communication Services/Interactive Media & Services
# 77416                     US Companies/Consumer Staples/Alcohol & Tobacco/Tobacco
# 77434                     US Companies/Consumer Staples/Alcohol & Tobacco/Tobacco
# 1054716                                                Global Companies/Materials
# 766235                                 US Companies/Real Estate/Specialized REITs
# 766293                                 US Companies/Real Estate/Specialized REITs
# 685553     US Companies/Consumer Staples/Personal Products/Personal Care Products
# 884404                                               Global Companies/Industrials
# 884406                                               Global Companies/Industrials
# 884405                                               Global Companies/Industrials
# 536387                                    Global Companies/Information Technology
#
#                                        Filename period_duration_type  \
# 130334                   Yum Brands YUM US.xlsx       fiscal_quarter
# 131345                   Yum Brands YUM US.xlsx       fiscal_quarter
# 131113                   Yum Brands YUM US.xlsx       fiscal_quarter
# 130945                   Yum Brands YUM US.xlsx       fiscal_quarter
# 351076                      Yandex YNDX US.xlsx          fiscal_year
# 351097                      Yandex YNDX US.xlsx          fiscal_year
# 77416    Philip Morris International PM US.xlsx          fiscal_year
# 77434    Philip Morris International PM US.xlsx          fiscal_year
# 1054716             ArcelorMittal SA MT US.xlsx          fiscal_year
# 766235                Iron Mountain IRM US.xlsx          fiscal_year
# 766293                Iron Mountain IRM US.xlsx       fiscal_quarter
# 685553          Herbalife Nutrition HLF US.xlsx          fiscal_year
# 884404                      Embraer ERJ US.xlsx       fiscal_quarter
# 884406                      Embraer ERJ US.xlsx       fiscal_quarter
# 884405                      Embraer ERJ US.xlsx       fiscal_quarter
# 536387                   Amadeus IT AMS SM.xlsx          fiscal_year
#
#           unit_type  value        CSIN  search_matches
# 130334        count  42.00  PV0XAZ0182               1
# 131345        count  42.00  PV0XAZ0182               1
# 131113        count  42.00  PV0XAZ0182               1
# 130945        count  42.00  PV0XAZ0182               1
# 351076     currency    NaN  UYDBUY0107               1
# 351097     currency    NaN  UYDBUY0107               1
# 77416      currency    NaN  LPNBZH0187               1
# 77434    percentage    NaN  LPNBZH0187               1
# 1054716    currency    NaN  A8NPYA0158               1
# 766235     currency    NaN  68GJOU0144               1
# 766293     currency   0.00  68GJOU0144               1
# 685553     currency    NaN  9YOTGA0170               1
# 884404        count   5.00  HODOVT0193               1
# 884406        count   0.00  HODOVT0193               1
# 884405        count   5.00  HODOVT0193               1
# 536387        count    NaN  E5EM5T0130               1

# %% [markdown]
# ## or we can search in guidance ...

# %%
#search for a company (our filenames include company names)
canalyst_search.search_guidance_time_series(ticker = "", #any ticker or list of tickers 
                sector="Consumer", #path in our nomenclature is a hierarchy of sectors
                time_series_name="", #our range name
                time_series_description="china", #human readable row header
                most_recent=True) #most recent item or all items
# Out:
#        ticker                                     Path  \
# 8708  STLA IM  Global Companies/Consumer Discretionary
# 205    ADS GR  Global Companies/Consumer Discretionary
#
#                      Filename  \
# 8708  Stellantis STLA IM.xlsx
# 205        ADIDAS ADS GR.xlsx
#
#                                time_series_description  \
# 8708                    China Industry Sales Growth, %
# 205   Greater China currency-neutral revenue growth, %
#
#                                                          time_series_name  \
# 8708                          z_V8B4RK0142_MO_OS_ChinaIndustrySalesGrowth
# 205   z_ZX5UFV0197_MO_OS_GreaterChinaproformacurrencyneutralrevenuegrowth
#
#      Fiscal Period   Low  Mid  High    Type.1                 Date  \
# 8708        FY2021  0.05 0.05  0.05  Estimate  2021-10-28 00:00:00
# 205         FY2021   0.2 0.25   0.3  Estimate  2021-03-10 00:00:00
#
#                Link  search_matches
# 8708  Press Release               1
# 205   Annual Report               1

# %% [markdown]
# ## or we can add filters such as must be greater than 5%

# %%
#search for banks which have revenue growth > 5%
canalyst_search.search_time_series(ticker = "",
                 sector="Thrifts",
                 category="",
                 unit_type="percentage",
                 mo_only=True,
                 period_duration_type='fiscal_quarter',
                 time_series_name='',
                 time_series_description='total revenue growth', #guessing on the time series name
                 query = 'value > 5')
# Out:
# No.of.unique tickers:  6
# No.of.unique time series:  6
#           ticker                               time_series_description  \
# 283664   TREE US                               Total Revenue Growth, %
# 984718     WD US                               Total Revenue Growth, %
# 688992     AX US                    Total Noninterest Income Growth, %
# 1039352  NYCB US                    Total Noninterest Income Growth, %
# 1039306  NYCB US         Total Earning Assets - Avg. Balance Growth, %
# 925665    AGM US    Total Earning Assets - Average of Period Growth, %
# 689122     AX US  Noninterest-bearing Deposit as a % of Total Deposits
# 1039491  NYCB US  Noninterest-bearing Deposit as a % of Total Deposits
# 688938     AX US                         Net Interest Income Growth, %
# 1020512   RDN US                     Return on Average Total Assets, %
#
#            time_series_name  is_driver                 category  \
# 283664   MO_GA_TotalRevenue      False          Growth Analysis
# 984718   MO_GA_TotalRevenue      False          Growth Analysis
# 688992    MO_GA_NonIIGrowth       True  Noninterest Income (FS)
# 1039352   MO_GA_NonIIGrowth      False  Noninterest Income (FS)
# 1039306   MO_GA_AssetGrowth      False          Growth Analysis
# 925665    MO_GA_AssetGrowth      False          Growth Analysis
# 689122         MO_BSS_NIBDR       True    Balance Sheet Summary
# 1039491        MO_BSS_NIBDR       True    Balance Sheet Summary
# 688938      MO_GA_NIIGrowth      False          Growth Analysis
# 1020512          MO_BSS_ROA      False    Balance Sheet Summary
#
#                                                              Path  \
# 283664   US Companies/Financials/Banks/Thrifts & Mortgage Finance
# 984718   US Companies/Financials/Banks/Thrifts & Mortgage Finance
# 688992   US Companies/Financials/Banks/Thrifts & Mortgage Finance
# 1039352  US Companies/Financials/Banks/Thrifts & Mortgage Finance
# 1039306  US Companies/Financials/Banks/Thrifts & Mortgage Finance
# 925665   US Companies/Financials/Banks/Thrifts & Mortgage Finance
# 689122   US Companies/Financials/Banks/Thrifts & Mortgage Finance
# 1039491  US Companies/Financials/Banks/Thrifts & Mortgage Finance
# 688938   US Companies/Financials/Banks/Thrifts & Mortgage Finance
# 1020512  US Companies/Financials/Banks/Thrifts & Mortgage Finance
#
#                                                       Filename  \
# 283664                                LendingTree TREE US.xlsx
# 984718                              Walker & Dunlop WD US.xlsx
# 688992                               Axos Financial AX US.xlsx
# 1039352                New York Community Bancorp NYCB US.xlsx
# 1039306                New York Community Bancorp NYCB US.xlsx
# 925665   Federal Agricultural Mortgage Corporation AGM US.xlsx
# 689122                               Axos Financial AX US.xlsx
# 1039491                New York Community Bancorp NYCB US.xlsx
# 688938                               Axos Financial AX US.xlsx
# 1020512                               Radian Group RDN US.xlsx
#
#         period_duration_type   unit_type  value        CSIN  search_matches
# 283664        fiscal_quarter  percentage  35.05  AQMYNB0181               3
# 984718        fiscal_quarter  percentage  16.44  AMV5NV0170               3
# 688992        fiscal_quarter  percentage   7.20  QWD0R50144               2
# 1039352       fiscal_quarter  percentage   6.43  ZK9U0K0155               2
# 1039306       fiscal_quarter  percentage   6.13  ZK9U0K0155               2
# 925665        fiscal_quarter  percentage   5.09  KMXGEB0171               2
# 689122        fiscal_quarter  percentage  31.36  QWD0R50144               1
# 1039491       fiscal_quarter  percentage  12.93  ZK9U0K0155               1
# 688938        fiscal_quarter  percentage   8.56  QWD0R50144               1
# 1020512       fiscal_quarter  percentage   6.25  U4FY7C0143               1

# %% [markdown]
# ## lastly, just return the most recent guidance for a couple of tickers

# %%
#just two tickers, only most recent item
canalyst_search.search_guidance_time_series(ticker = ["AMZN US","FB US"],
                sector="",
                time_series_description="",
                most_recent=True)
# Out:
#        ticker  \
# 3658    FB US
# 3657    FB US
# 3656    FB US
# 639   AMZN US
# 638   AMZN US
#
#                                                                                       Path  \
# 3658                      US Companies/Communication Services/Interactive Media & Services
# 3657                      US Companies/Communication Services/Interactive Media & Services
# 3656                      US Companies/Communication Services/Interactive Media & Services
# 639   US Companies/Consumer Discretionary/Online Product & Services/Internet Direct Retail
# 638   US Companies/Consumer Discretionary/Online Product & Services/Internet Direct Retail
#
#                                          Filename  \
# 3658  Meta Platforms (f.k.a. Facebook) FB US.xlsx
# 3657  Meta Platforms (f.k.a. Facebook) FB US.xlsx
# 3656  Meta Platforms (f.k.a. Facebook) FB US.xlsx
# 639                       Amazon.com AMZN US.xlsx
# 638                       Amazon.com AMZN US.xlsx
#
#           time_series_description    time_series_name Fiscal Period       Low  \
# 3658                  Net Revenue          MO_RIS_REV       Q1-2022   27000.0
# 3657  Y/Y Total revenue growth, %  MO_GA_TotalRevenue       Q1-2022      0.03
# 3656                        Capex      MO_CFSum_Capex        FY2022  -29000.0
# 639                   Net Revenue          MO_RIS_Rev       Q1-2022  112000.0
# 638              Operating income         MO_RIS_EBIT       Q1-2022    3000.0
#
#            Mid      High    Type.1                 Date           Link  \
# 3658  28000.00   29000.0  Estimate  2022-02-02 00:00:00  Press Release
# 3657      0.07      0.11  Estimate  2022-02-02 00:00:00  Press Release
# 3656 -31500.00  -34000.0  Estimate  2022-02-02 00:00:00  Press Release
# 639  114500.00  117000.0  Estimate  2022-02-03 00:00:00  Press Release
# 638    4500.00    6000.0  Estimate  2022-02-03 00:00:00  Press Release
#
#       search_matches
# 3658               1
# 3657               1
# 3656               1
# 639                1
# 638                1

# %%
canalyst_search.kpi_match("SQ US","AXP US").head(20)
# Out:
# No.of.unique tickers:  1
# No.of.unique time series:  545
# No.of.unique tickers:  1
# No.of.unique time series:  425
# 0   ticker_x ticker_y   unit_type                      time_series_name_x  \
# 103    SQ US   AXP US       count                   MO_RIS_ShareCount_WAD
# 3      SQ US   AXP US       count               MO_RIS_ShareCount_WAD_Adj
# 69     SQ US   AXP US       count                    MO_KPI_EmployeeCount
# 38     SQ US   AXP US    currency                    MO_RIS_NI_GAAP_Basic
# 102    SQ US   AXP US       count                   MO_RIS_ShareCount_WAB
# 42     SQ US   AXP US    currency       z_8MPZ580137_MO_RIS_GAAPOtherOPEX
# 35     SQ US   AXP US       ratio                          MO_RIS_EPS_WAD
# 64     SQ US   AXP US    currency    z_8MPZ580137_MO_RIS_NonGAAPOtherOPEX
# 39     SQ US   AXP US    currency                  MO_RIS_NI_GAAP_Diluted
# 57     SQ US   AXP US       ratio                      MO_RIS_EPS_WAD_Adj
# 34     SQ US   AXP US       ratio                          MO_RIS_EPS_WAB
# 56     SQ US   AXP US  percentage                            MO_MA_EBITDA
# 15     SQ US   AXP US  percentage                        MO_MA_EBITDA_Adj
# 44     SQ US   AXP US  percentage                                MO_MA_RD
# 45     SQ US   AXP US  percentage                                MO_MA_SM
# 36     SQ US   AXP US  percentage                                MO_MA_GA
# 37     SQ US   AXP US  percentage                                MO_MA_GM
# 59     SQ US   AXP US    currency                       MO_RIS_GA_NONGAAP
# 66     SQ US   AXP US    currency                       MO_RIS_RD_NONGAAP
# 125    SQ US   AXP US    currency  z_8MPZ580137_MO_OS_UnitedStatesRevenue
#
# 0                           time_series_description_x  \
# 103                          Shares Outstanding - WAD
# 3                   Adjusted Shares Outstanding - WAD
# 69                Number of Employees, # of employees
# 38     GAAP Net Income to common shareholders - Basic
# 102                          Shares Outstanding - WAB
# 42                                    GAAP Other OPEX
# 35                      GAAP Earnings Per Share - WAD
# 64                                Non-GAAP Other OPEX
# 39   GAAP Net Income to common shareholders - Diluted
# 57                  Non-GAAP Earnings Per Share - WAD
# 34                      GAAP Earnings Per Share - WAB
# 56                          Non-GAAP EBITDA Margin, %
# 15         Company Reported Non-GAAP EBITDA Margin, %
# 44                                 GAAP R&D Margin, %
# 45                                 GAAP S&M Margin, %
# 36                                 GAAP G&A Margin, %
# 37                               GAAP Gross Margin, %
# 59                                       Non-GAAP G&A
# 66                                       Non-GAAP R&D
# 125                         United States Revenue, mm
#
# 0                         time_series_name_y  \
# 103                    MO_RIS_ShareCount_WAD
# 3                      MO_RIS_ShareCount_WAD
# 69                      MO_KPI_EmployeeCount
# 38                      MO_RIS_NI_GAAP_Basic
# 102                    MO_RIS_ShareCount_WAD
# 42                               MO_RIS_OPEX
# 35                            MO_RIS_EPS_WAD
# 64                               MO_RIS_OPEX
# 39                      MO_RIS_NI_GAAP_Basic
# 57                            MO_RIS_EPS_WAD
# 34                            MO_RIS_EPS_WAD
# 56                                 MO_MA_EBT
# 15                                 MO_MA_EBT
# 44                                 MO_MA_EBT
# 45                                 MO_MA_EBT
# 36                                 MO_MA_EBT
# 37                                 MO_MA_EBT
# 59       MO_RIS_Adjustments_Dilution_NONGAAP
# 66       MO_RIS_Adjustments_Dilution_NONGAAP
# 125  z_FYXPQQ0114_MO_OS_Noninterestrevenue_3
#
# 0                       time_series_description_y  is_driver_x  is_driver_y  \
# 103                      Shares Outstanding - WAD        False        False
# 3                        Shares Outstanding - WAD        False        False
# 69                 Employee Count, # of employees        False        False
# 38              Net Income to Common Shareholders        False        False
# 102                      Shares Outstanding - WAD        False        False
# 42                                           OPEX        False        False
# 35                       Earnings Per Share - WAD        False        False
# 64                                           OPEX        False        False
# 39              Net Income to Common Shareholders        False        False
# 57                       Earnings Per Share - WAD        False        False
# 34                       Earnings Per Share - WAD        False        False
# 56            EBT Margin (adj. One-time Items), %        False        False
# 15            EBT Margin (adj. One-time Items), %        False        False
# 44            EBT Margin (adj. One-time Items), %        False        False
# 45            EBT Margin (adj. One-time Items), %        False        False
# 36            EBT Margin (adj. One-time Items), %        False        False
# 37            EBT Margin (adj. One-time Items), %        False        False
# 59   Non-GAAP Adjustments for Dilutive Securities        False        False
# 66   Non-GAAP Adjustments for Dilutive Securities        False        False
# 125                 USCS Non-interest revenue, mm        False        False
#
# 0    word_score  diff_score  word_plus_diff_score
# 103        1.19        1.00                  2.19
# 3          1.19        0.91                  2.10
# 69         0.95        1.00                  1.95
# 38         0.62        1.00                  1.62
# 102        0.67        0.95                  1.62
# 42         1.00        0.50                  1.50
# 35         0.47        1.00                  1.47
# 64         1.00        0.47                  1.47
# 39         0.62        0.76                  1.38
# 57         0.47        0.88                  1.34
# 34         0.18        0.93                  1.11
# 56         0.03        0.86                  0.88
# 15         0.03        0.72                  0.75
# 44         0.03        0.71                  0.73
# 45         0.03        0.71                  0.73
# 36         0.03        0.71                  0.73
# 37         0.03        0.71                  0.73
# 59         0.10        0.62                  0.72
# 66         0.10        0.62                  0.72
# 125        0.08        0.62                  0.71

# %%
#canalyst_search.kpi_correlations(subsector="Data Processing _ Outsourced Services",mo_only=True)
canalyst_search.kpi_correlations("SQ US")
# Out:
#       ticker_y  ticker_x  \
# 1124     SQ US    AMS SM
# 2240     SQ US   WISE LN
# 4381   RELY US     SQ US
# 4985     SQ US   EDEN FP
# 5112     SQ US   TOST US
# 5611     SQ US    AMS SM
# 5744   RELY US     SQ US
# 6017     MA US     SQ US
# 6191     SQ US   WISE LN
# 9631     MQ US     SQ US
# 11107    SQ US   TOST US
# 11918    SQ US    AMS SM
# 15167  RPAY US     SQ US
# 16467    SQ US    AMS SM
# 17544    SQ US      V US
# 23395   GPN US     SQ US
# 24112    SQ US    AMS SM
# 24716    SQ US   WISE LN
# 26933    SQ US  ADYEN NA
#
#                                                     time_series_description_y  \
# 1124                               Intangible Amortization + Acquisition Adj.
# 2240           Y/Y Cash App Subscription and services-based revenue growth, %
# 4381                                             R&D Margin (adj. for SBC), %
# 4985   Y/Y Seller Ecosystem Subscription and services-based revenue growth, %
# 5112                                            Y/Y Bitcoin revenue growth, %
# 5611                                   Transaction-based GAAP gross margin, %
# 5744                                        Q/Q growth in Active Customers, %
# 6017                                       Y/Y improvement in G&A margin, bps
# 6191               Seller Transaction-based Revenue as a percentage of GPV, %
# 9631                       Compensation and benefits Margin (adj. for SBC), %
# 11107                                          Y/Y Hardware revenue growth, %
# 11918                    Subscription and services-based GAAP gross margin, %
# 15167          Repay processing and service fees percentage of card volume, %
# 16467                                 Amortization of acquired technology, mm
# 17544                Cash App marketing cost margin, % of Cash App Revenue, %
# 23395                       Business and Consumer solutions Revenue Growth, %
# 24112                                                  Non-GAAP G&A Margin, %
# 24716                                           Bitcoin GAAP gross margin , %
# 26933                            Non-GAAP Adjustments to Net Interest Expense
#
#                                                     time_series_description_x  \
# 1124                                  D&A acquisition related costs & PPA, mm
# 2240                                   Business Volume per customer growth, %
# 4381                                                   Non-GAAP R&D Margin, %
# 4985                         Brazil operating revenue like-for-like growth, %
# 5112         Y/Y Average subscription services revenue per location growth, %
# 5611                              Western Europe passengers boarded growth, %
# 5744               Seller Transaction-based Revenue as a percentage of GPV, %
# 6017   Y/Y Seller Ecosystem Subscription and services-based revenue growth, %
# 6191                            Change in Active Unique Personal Customers, %
# 9631                 Cash App marketing cost margin, % of Cash App Revenue, %
# 11107                                  Y/Y Average GPV per location growth, %
# 11918                               Underlying IT Solutions revenue growth, %
# 15167          Y/Y Cash App Subscription and services-based revenue growth, %
# 16467                                 D&A acquisition related costs & PPA, mm
# 17544                   Client incentives as % of gross operating revenues, %
# 23395                                  Transaction-based GAAP gross margin, %
# 24112                             Western Europe passengers boarded growth, %
# 24716                           Change in Active Unique Business Customers, %
# 26933                                                                  EBITDA
#
#                                                                 time_series_name_y  \
# 1124                                                          MO_RIS_DAintangibles
# 2240           z_8MPZ580137_MO_GA_CashAppSubscriptionandservicesbasedrevenuegrowth
# 4381                                                                  MO_MA_RD_Adj
# 4985   z_8MPZ580137_MO_GA_SellerEcosystemSubscriptionandservicesbasedrevenuegrowth
# 5112                                             z_8MPZ580137_MO_OS_Bitcoinrevenue
# 5611                                z_8MPZ580137_MO_OS_Transactionbasedgrossmargin
# 5744                                  z_WLMN8S0182_MO_OS_QQgrowthinActivecustomers
# 6017                                    z_GSYQ3D0168_MO_OS_YYimprovementinGAmargin
# 6191            z_8MPZ580137_MO_OS_SellerTransactionbasedRevenueasapercentageofGPV
# 9631                     z_7HOOO20139_MO_MA_CompensationandbenefitsMarginadjforSBC
# 11107                                     z_8MPZ580137_MO_OS_Hardwarerevenuegrowth
# 11918                   z_8MPZ580137_MO_OS_Subscriptionandservicesbasedgrossmargin
# 15167                           z_LSJN3H0159_MO_OS_Repayprocessingandservicefees_1
# 16467                          z_8MPZ580137_MO_OS_Amortizationofacquiredtechnology
# 17544                                z_8MPZ580137_MO_OS_CashAppmarketingcostmargin
# 23395                 z_ED4A2Y0118_MO_GA_BusinessandConsumersolutionsRevenueGrowth
# 24112                                                             MO_MA_GA_NONGAAP
# 24716                                        z_8MPZ580137_MO_OS_Bitcoingrossmargin
# 26933                                                MO_RIS_IE_NONGAAP_Adjustments
#
#                                                                 time_series_name_x  \
# 1124                               z_E5EM5T0130_MO_OS_DAacquisitionrelatedcostsPPA
# 2240                            z_E5M88V0122_MO_OS_BusinessVolumepercustomergrowth
# 4381                                                              MO_MA_RD_NONGAAP
# 4985                        z_14U6ZP0135_MO_OS_Braziloperatingrevenueorganicgrowth
# 5112             z_58EYYK0156_MO_OS_AveragesubscriptionrevenueperlocationgrowthYoY
# 5611                       z_E5EM5T0130_MO_OS_WesternEuropepassengersboardedgrowth
# 5744            z_8MPZ580137_MO_OS_SellerTransactionbasedRevenueasapercentageofGPV
# 6017   z_8MPZ580137_MO_GA_SellerEcosystemSubscriptionandservicesbasedrevenuegrowth
# 6191                            z_E5M88V0122_MO_OS_ChangeinActivePersonalCustomers
# 9631                                 z_8MPZ580137_MO_OS_CashAppmarketingcostmargin
# 11107                            z_58EYYK0156_MO_OS_AverageGPVperLocationgrowthYoY
# 11918                        z_E5EM5T0130_MO_GA_UnderlyingITSolutionsrevenuegrowth
# 15167          z_8MPZ580137_MO_GA_CashAppSubscriptionandservicesbasedrevenuegrowth
# 16467                              z_E5EM5T0130_MO_OS_DAacquisitionrelatedcostsPPA
# 17544                z_2CRCA60110_MO_OS_clientincentivesasofgrossoperatingrevenues
# 23395                               z_8MPZ580137_MO_OS_Transactionbasedgrossmargin
# 24112                      z_E5EM5T0130_MO_OS_WesternEuropepassengersboardedgrowth
# 24716                           z_E5M88V0122_MO_OS_ChangeinActiveBusinessCustomers
# 26933                                                                MO_RIS_EBITDA
#
#        rsquared                              subsector
# 1124       0.95  Data Processing _ Outsourced Services
# 2240       0.95  Data Processing _ Outsourced Services
# 4381       0.94  Data Processing _ Outsourced Services
# 4985       0.94  Data Processing _ Outsourced Services
# 5112       0.94  Data Processing _ Outsourced Services
# 5611       0.94  Data Processing _ Outsourced Services
# 5744       0.94  Data Processing _ Outsourced Services
# 6017       0.93  Data Processing _ Outsourced Services
# 6191       0.93  Data Processing _ Outsourced Services
# 9631       0.92  Data Processing _ Outsourced Services
# 11107      0.91  Data Processing _ Outsourced Services
# 11918      0.90  Data Processing _ Outsourced Services
# 15167      0.88  Data Processing _ Outsourced Services
# 16467      0.87  Data Processing _ Outsourced Services
# 17544      0.86  Data Processing _ Outsourced Services
# 23395      0.81  Data Processing _ Outsourced Services
# 24112      0.80  Data Processing _ Outsourced Services
# 24716      0.80  Data Processing _ Outsourced Services
# 26933      0.77  Data Processing _ Outsourced Services

# %%
#we use Bloomberg tickers
ticker_list = ["AMZN US","FB US"]

#our database is built on analyst models, so we call it a "modelbase"

#everything candas feeds off the model object

#instantiate a Model object
#authorization is handled within the object
model_set = cd.ModelSet(ticker_list=ticker_list,config=config)

time_series_names=['MO_RIS_REV','MO_RIS_EBITDA_Adj']
model_set.model_frame(time_series_name=time_series_names,
                  pivot=True,
                  period_duration_type='fiscal_year', #or fiscal_year
                  #is_historical=True,
                  #n_periods=12,
                  #mrq_notation=False
                          )
# Out:
# period_name_sorted   ticker  name_index                  category  \
# 0                   AMZN US      352.00  Revised Income Statement
# 2                     FB US      368.00  Revised Income Statement
# 1                   AMZN US      371.00  Revised Income Statement
# 3                     FB US      385.00  Revised Income Statement
#
# period_name_sorted   time_series_name           time_series_description  \
# 0                          MO_RIS_REV                       Net Revenue
# 2                          MO_RIS_REV                       Net Revenue
# 1                   MO_RIS_EBITDA_Adj  Adjusted EBITDA (No Adjustments)
# 3                   MO_RIS_EBITDA_Adj  Adjusted EBITDA (No Adjustments)
#
# period_name_sorted  is_driver     MRFQ         2009FY         2010FY  \
# 0                       False  Q4-2021 24509000000.00 34204000000.00
# 2                       False  Q4-2021   777000000.00  1974000000.00
# 1                       False  Q4-2021  1848000000.00  2398000000.00
# 3                       False  Q4-2021   367000000.00  1191000000.00
#
# period_name_sorted         2011FY  ...          2017FY          2018FY  \
# 0                  48077000000.00  ... 177866000000.00 232887000000.00
# 2                   3711000000.00  ...  40653000000.00  55838000000.00
# 1                   2502000000.00  ...  19799000000.00  33180000000.00
# 3                   2296000000.00  ...  26951000000.00  33380000000.00
#
# period_name_sorted          2019FY          2020FY          2021FY  \
# 0                  280522000000.00 386064000000.00 469822000000.00
# 2                   70697000000.00  85965000000.00 117929000000.00
# 1                   43194000000.00  57358000000.00  71932000000.00
# 3                   34563000000.00  46069000000.00  63884000000.00
#
# period_name_sorted          2022FY          2023FY          2024FY  \
# 0                  520447620000.00 612792512950.00 711748425703.50
# 2                  131553147491.64 153407601234.55 175295059922.05
# 1                   76878587342.94  98832461255.32 133939114244.15
# 3                   61284394178.71  70364768132.88  81881542406.01
#
# period_name_sorted          2025FY          2026FY
# 0                  831962240979.49 969009244903.01
# 2                  202021804909.23 233722596477.74
# 1                  156189610350.52 186258049092.45
# 3                   96546595055.84 113380741620.41
#
# [4 rows x 25 columns]
