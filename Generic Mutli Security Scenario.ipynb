# %% [markdown]
# # Imports

# %%
from IPython.display import display as dsp
from datetime import datetime as dt
from random import sample


import sys
import os
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.max_colwidth', 400)

import canalyst_candas.candas as cd
from canalyst_candas.configuration.config import Config

config_info = {
  "canalyst_api_key": "",
  "s3_access_key_id": "",
  "s3_secret_key": "",
  "fred_key": "",
  "default_dir": "",
  "mds_host": "",
  "wp_host": ""
}

config = Config(config=config_info)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# A configuration file has been created for you in
# /home/canalyst-candas/canalyst/keys.json. For Excel file downloads and scenario
# mapping, you'll need to add an API key to the 'canalyst_api_key'
# value. Visit https://app.canalyst.com/settings/api-tokens to create
# and retrieve your API key. You will also need to retrieve your
# S3 Access ID and Secret Key and fill in 'canalyst_s3_id' and
# 'canalyst_s3_key' with those values, respectively. If using a
# Jupyter Notebook, stop and restart the notebook for the changes to
# take effect. If using a Python/iPython session, quit the current
# session and start a new one.
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Establish an Interest List

# %%
ir_list = [
"AC CN",
"ALK US",
"ALGT US",
"AAL US",
"CPA US",
"DAL US",
"ULCC US",
"HA US",
"JBLU US",
"LUV US",
"SAVE US",
"UAL US",
]

# %% [markdown]
# # Creating A Search Object

# %%
# Instantiate new search object:
search = cd.Search(config)

# %% [markdown]
# # Searching for Common Time Series Which Are Drivers

# %%
search_results_df = search.search_time_series(
    ticker = ir_list,
    time_series_name="",
    is_driver=True   
)
# Common time series:
gpd_search = search_results_df.groupby("time_series_name")[["ticker"]].nunique().reset_index().copy()
gpd_search.sort_values(by="ticker", ascending=False, inplace=True)
gpd_search.head(20)
# Out:
# Building search index...
# No.of.unique tickers:  12
# No.of.unique time series:  311
#                     time_series_name  ticker
# 53           MO_RIS_TaxRate_Deferred      12
# 48                         MO_RIS_OI      12
# 4               MO_CFSum_Acquisition      12
# 5                     MO_CFSum_Capex      12
# 6                       MO_CFSum_DPS      12
# 7               MO_CFSum_Divestiture      12
# 52            MO_RIS_TaxRate_Current      12
# 42        MO_RIS_Adjustments_NONGAAP      11
# 8           MO_CFSum_NetDebtIssuance      11
# 9                 MO_CFSum_NetShares      11
# 10          MO_CFSum_NetShares_Price      11
# 1           MO_BSS_InterestRate_Debt      10
# 0           MO_BSS_InterestRate_Cash      10
# 12               MO_DAF_D_Percentage       8
# 49                        MO_RIS_OTI       8
# 13  MO_DAF_Intangibles_Capex_Percent       6
# 11               MO_DAF_A_Percentage       6
# 55           MO_WCF_AR_Margin_Change       6
# 54           MO_WCF_AP_Margin_Change       6
# 36   MO_OS_LoadFactor_Pacific_Growth       4

# %%
search_results_df = search.search_time_series(
    ticker = ir_list,
    time_series_name="eps",
    mo_only=True
)
# Common time series:
gpd_search = search_results_df.groupby("time_series_name")[["ticker"]].nunique().reset_index().copy()
gpd_search.sort_values(by="ticker", ascending=False, inplace=True)
gpd_search.head(10)
# Out:
# No.of.unique tickers:  12
# No.of.unique time series:  3
#      time_series_name  ticker
# 0      MO_RIS_EPS_WAB      12
# 1      MO_RIS_EPS_WAD      12
# 2  MO_RIS_EPS_WAD_Adj      12

# %%
ts = "MO_BSS_InterestRate_Debt"
search_results_df = search.search_time_series(
    ticker=ir_list,
    time_series_name=ts,
    unit_type='percentage',
    is_driver=True
)
# Out:
# No.of.unique tickers:  10
# No.of.unique time series:  1

# %%
# A list of tickers for this driver:
ir_tickers = list(search_results_df[search_results_df["time_series_name"] == ts]["ticker"].unique())
len(ir_tickers)
# Out:
# 10

# %% [markdown]
# # Create a Model Set of Target Companies

# %%
# Create a model set form this ticker list:

ir_set = cd.ModelSet(ticker_list=ir_tickers, config=config, allow_nulls=True)
# Out:
# Please instantiate ModelSet with a list of tickers, even a list of one.

# %%
# Create params:
df_params = ir_set.forecast_frame(ts,
                             n_periods=4,
                             function_name='add',
                             function_value=1)
df_params = df_params[df_params['value']!=0]
dsp(df_params.shape)
dsp(df_params.head())
# Out:
# (40, 7)
#        ticker period_name          time_series_name  \
# 3284  JBLU US     Q1-2022  MO_BSS_InterestRate_Debt
# 3677   LUV US     Q1-2022  MO_BSS_InterestRate_Debt
# 3703  SAVE US     Q1-2022  MO_BSS_InterestRate_Debt
# 3785    HA US     Q1-2022  MO_BSS_InterestRate_Debt
# 4052  ALGT US     Q1-2022  MO_BSS_InterestRate_Debt
#
#               time_series_description   value  new_value period_end_date
# 3284  Effective Interest Rate on Debt 4.10000    5.10000      2022-03-31
# 3677  Effective Interest Rate on Debt 4.00000    5.00000      2022-03-31
# 3703  Effective Interest Rate on Debt 4.50000    5.50000      2022-03-31
# 3785  Effective Interest Rate on Debt 5.60000    6.60000      2022-03-31
# 4052  Effective Interest Rate on Debt 4.20000    5.20000      2022-03-31

# %%
sample_tickers = list(df_params["ticker"].unique())
sample_params = df_params[df_params["ticker"].isin(sample_tickers)].copy()
len(sample_tickers)
# Out:
# 10

# %% [markdown]
# # Run Scenarios on Common Time Series

# %%
start = dt.now()

# How much does revenue move?
return_series = "MO_RIS_EPS_WAD_Adj"

# Scenarios for a sample of 10:
dicts_output=ir_set.fit(sample_params,return_series)

# Print time:
dsp((dt.now() - start).seconds)
# Out:
# ALK US scenario_id_url: https://mds.canalyst.com/api/equity-model-series/E82OUG0135/equity-models/FY2021.20/scenarios/QTV1F6KpU5G2c4DMWYzjkg/
# UAL US scenario_id_url: https://mds.canalyst.com/api/equity-model-series/K25QNC0129/equity-models/FY2021.23/scenarios/iWcKpgBZUnG-Xd3KbRo3bg/
# AAL US scenario_id_url: https://mds.canalyst.com/api/equity-model-series/DYKK2Y0171/equity-models/FY2021.20/scenarios/1lZ2EtDpW8Kq7mYbyVl9Iw/
# LUV US scenario_id_url: https://mds.canalyst.com/api/equity-model-series/SAQ7HK0156/equity-models/FY2021.20/scenarios/4Er-G-wKU92erEvDhj_0LQ/
# HA US scenario_id_url: https://mds.canalyst.com/api/equity-model-series/XGJ4AE0144/equity-models/FY2021.20/scenarios/LqyXDwzIXXKZp1FKykTikg/
# AC CN scenario_id_url: https://mds.canalyst.com/api/equity-model-series/9O09KW0128/equity-models/Q3-2021.21/scenarios/0TUwyGcRVQ66kSSDkD91Rw/
# DAL US scenario_id_url: https://mds.canalyst.com/api/equity-model-series/2EFOXB0147/equity-models/FY2021.20/scenarios/3yjqKeEdXGGJNohQDd7M2g/
# ALGT US scenario_id_url: https://mds.canalyst.com/api/equity-model-series/UCMZVJ0104/equity-models/Q3-2021.22/scenarios/02Atp5NEUASsJDBPOV2bDQ/
# SAVE US scenario_id_url: https://mds.canalyst.com/api/equity-model-series/0PVHY00148/equity-models/Q3-2021.20/scenarios/3reW7CZ0W3Cb74WH5OYI6Q/
# JBLU US scenario_id_url: https://mds.canalyst.com/api/equity-model-series/9P9H220191/equity-models/FY2021.22/scenarios/t1z8BpgGX82PeVZXkHznmg/
# 60

# %% [markdown]
# # Rank Ordered Results

# %%
# Show scenario results:
list_df = []
for k in dicts_output.keys():
    df = dicts_output[k].head(1)
    list_df.append(df)
pd.concat(list_df).sort_values('diff')
# Out:
#     ticker period_name    time_series_name            time_series_description  \
# 0  SAVE US     Q4-2021  MO_RIS_EPS_WAD_Adj  Adjusted Earnings Per Share - WAD
# 0   UAL US     Q1-2022  MO_RIS_EPS_WAD_Adj  Adjusted Earnings Per Share - WAD
# 0  ALGT US     Q4-2021  MO_RIS_EPS_WAD_Adj  Adjusted Earnings Per Share - WAD
# 0   AAL US     Q1-2022  MO_RIS_EPS_WAD_Adj  Adjusted Earnings Per Share - WAD
# 0    AC CN     Q4-2021  MO_RIS_EPS_WAD_Adj  Adjusted Earnings Per Share - WAD
# 0  JBLU US     Q1-2022  MO_RIS_EPS_WAD_Adj  Adjusted Earnings Per Share - WAD
# 0   LUV US     Q1-2022  MO_RIS_EPS_WAD_Adj  Adjusted Earnings Per Share - WAD
# 0    HA US     Q1-2022  MO_RIS_EPS_WAD_Adj  Adjusted Earnings Per Share - WAD
# 0   DAL US     Q1-2022  MO_RIS_EPS_WAD_Adj  Adjusted Earnings Per Share - WAD
# 0   ALK US     Q1-2022  MO_RIS_EPS_WAD_Adj  Adjusted Earnings Per Share - WAD
#
#    default       scenario    diff
# 0 -1.56106  -1.5610569492 1.00000
# 0 -5.20966  -5.2096557999 1.00000
# 0  2.62148   2.6214776886 1.00000
# 0 -1.35021  -1.3502134297 1.00000
# 0 -1.27607  -1.2760685093 1.00000
# 0 -0.59935  -0.9604456026 1.60247
# 0 -0.44975  -0.7692580813 1.71042
# 0 -1.30715  -3.2281527603 2.46960
# 0 -0.40007  -1.1762191937 2.94005
# 0 -0.50709  -2.0125171855 3.96875

# %% [markdown]
# # Investigate the PNL of one company

# %%
ticker = 'ALK US'
time_series_name = "MO_RIS_EPS_WAD_Adj"
target_model_set = cd.ModelSet(ticker_list=[ticker], config=config) 
model_map = target_model_set.create_model_map(ticker=ticker,
                            time_series_name=time_series_name,
                            tree = True,
                            notebook = True,
                            col_for_labels = "time_series_name") 
model_map.show()
# Out:
# https://mds.canalyst.com/api/equity-model-series/E82OUG0135/equity-models/FY2021.20/time-series/MO_RIS_EPS_WAD_Adj/forecast-data-points/Q1-2022/drivers/?format=dot
#         <iframe
#             width="1000px"
#             height="1000px"
#             src="ALK_MO_RIS_EPS_WAD_Adj_model_map.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Investigate one aspect of a company model, using most recent quarter

# %%
test_set = cd.ModelSet(ticker_list=['ALK US'], config=config, allow_nulls=True)
test_set.model_frame(mrq=True,
                     #time_series_name = 'cash|debt',
                     time_series_name='MO_BSS_InterestRate_Debt|cash|debt',
                     category='')[['time_series_description','time_series_name','value']].groupby('time_series_description').first().reset_index()
# Out:
# Please instantiate ModelSet with a list of tickers, even a list of one.
#                                       time_series_description  \
# 0                                                Adjusted EBT
# 1                              Adjusted Net Debt / LTM EBITDA
# 2                             Adjusted Net Debt / LTM EBITDAR
# 3                     Adjusted Net Debt / Operating Cash Flow
# 4                                      Beginning Cash Balance
# 5                                 Cash Flow Per Diluted Share
# 6                                   Cash and cash equivalents
# 7                                  Cash paid for acquisitions
# 8   Cash, short-term investments, and hedge margin receivable
# 9                          Consensus Estimates - Adjusted EBT
# 10          Consensus Estimates - Cash Flow Per Diluted Share
# 11                          Current portion of long-term debt
# 12                                                       Debt
# 13                               Debt (Incl. Aircraft Leases)
# 14                            Effective Interest Rate on Cash
# 15                            Effective Interest Rate on Debt
# 16                        Effective Net Interest Rate on Debt
# 17                                        Ending Cash Balance
# 18                          FCF, Post Div, Debt, Buyback, A/D
# 19                                                    LT Debt
# 20                                              LTM Cash Flow
# 21                     Long-Term Debt, Net of Current Portion
# 22                                    Long-term debt payments
# 23                                 Net Change in Cash Balance
# 24                                                   Net Debt
# 25                           Net Debt (Incl. Aircraft Leases)
# 26                              Net Debt Issuance (Repayment)
# 27                              Operating Cash Flow before WC
# 28                   Proceeds from issuance of long-term debt
# 29                                            Restricted cash
# 30                                                    ST Debt
# 31                       Total cash and marketable securities
#
#                                                    time_series_name  \
# 0                                    z_E82OUG0135_MO_AN_AdjustedEBT
# 1                                              MO_BSS_Debt_ToEBITDA
# 2                                             MO_BSS_Debt_ToEBITDAR
# 3                                                  MO_BSS_Debt_ToCF
# 4                                             MO_CCFS_Balance_Begin
# 5                                                     MO_CFSum_CFPS
# 6                                                        MO_BS_Cash
# 7                      z_E82OUG0135_MO_CCFS_Cashpaidforacquisitions
# 8                                                       MO_BSS_Cash
# 9                 z_E82OUG0135_MO_RIS_ConsensusEstimatesAdjustedEBT
# 10  z_E82OUG0135_MO_CFSum_ConsensusEstimatesCashFlowPerDilutedShare
# 11                  z_E82OUG0135_MO_BS_Currentportionoflongtermdebt
# 12                                                      MO_BSS_Debt
# 13                                                  MO_BSS_Debt_Adj
# 14                                         MO_BSS_InterestRate_Cash
# 15                                         MO_BSS_InterestRate_Debt
# 16                                      MO_BSS_NetInterestRate_Debt
# 17                                              MO_CCFS_Balance_End
# 18                    MO_CFSum_FCF_PostDivPostADPostDebtPostBuyback
# 19                                                   MO_BSS_Debt_LT
# 20                                  z_E82OUG0135_MO_BSS_LTMCashFlow
# 21                                  z_E82OUG0135_MO_BS_LongTermDebt
# 22                        z_E82OUG0135_MO_CCFS_Longtermdebtpayments
# 23                                                MO_CCFS_NetChange
# 24                                                  MO_BSS_Debt_Net
# 25                                              MO_BSS_Debt_Net_Adj
# 26                                         MO_CFSum_NetDebtIssuance
# 27                                            MO_CFSum_CFO_BeforeWC
# 28          z_E82OUG0135_MO_CCFS_Proceedsfromissuanceoflongtermdebt
# 29                                     MO_BS_RestrictedCash_Current
# 30                                                   MO_BSS_Debt_ST
# 31              z_E82OUG0135_MO_BS_Totalcashandmarketablesecurities
#
#                value
# 0    236000000.00000
# 1            2.01573
# 2            1.27596
# 3            0.65000
# 4   1386000000.00000
# 5            2.31940
# 6    495000000.00000
# 7            0.00000
# 8   3219000000.00000
# 9                NaN
# 10               NaN
# 11   425000000.00000
# 12  2650000000.00000
# 13  4116000000.00000
# 14           0.66243
# 15           4.07748
# 16           3.26199
# 17   519000000.00000
# 18  -334000000.00000
# 19  2225000000.00000
# 20  1380000000.00000
# 21  2225000000.00000
# 22 -1222000000.00000
# 23  -867000000.00000
# 24  -569000000.00000
# 25   897000000.00000
# 26  -541000000.00000
# 27   295000000.00000
# 28   363000000.00000
# 29    24000000.00000
# 30   425000000.00000
# 31  3195000000.00000
