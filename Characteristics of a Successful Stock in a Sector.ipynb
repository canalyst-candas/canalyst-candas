# %% [markdown]
# ## Includes

# %%
import sys
import os
import numpy as np
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.max_colwidth', 400)

import canalyst_candas.candas as cd
import canalyst_candas.candas_datareader as cdr
from canalyst_candas.configuration.config import Config


config_info = {
  "canalyst_api_key": "",
   "s3_access_key_id": "",
    "s3_secret_key": "",
  "fred_key": "",
  "default_dir": "",
  "mds_host": "",
  "wp_host": ""
}


config = Config(config=config_info)

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# A configuration file has been created for you in
# /Users/jedgore/canalyst/keys.json.
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Example: Characteristics of a Successful Stock in a Sector
# ## Workflow:
# <li>Set switches
# <li>Create target vector = "earnings sharpe ratio" or alpha post-EPS / standard deviation post-EPS
# <li>Create ModelSet for target list
# <li>Find common names
# <li>Create a model_frame of common names
# <li>Regress against target vector
# <li>List coefficients

# %% [markdown]
# ## Control Switches:
# ### Change ticker list as needed etc

# %%
yahoo_tickers = ['TJX',
'LULU',
'ROST',
'BURL',
'RL',
'GPS',
'LEVI',
'TPR',
'ZUMZ',
'CPRI',
'FL',
'CRI',
'AEO',
'URBN',
'BKE',
'GES',
'ANF']
target_list = ['TJX US',
'LULU US',
'ROST US',
'BURL US',
'RL US',
'GPS US',
'LEVI US',
'TPR US',
'ZUMZ US',
'CPRI US',
'FL US',
'CRI US',
'AEO US',
'URBN US',
'BKE US',
'GES US',
'ANF US']
index_ticker = "^GSPC"

# %% [markdown]
# ### Get price data and calculate alpha

# %%
price_list = []
for yahoo_ticker in yahoo_tickers:
    print(yahoo_ticker)
    df = cdr.get_earnings_and_prices(ticker=yahoo_ticker,index_ticker = index_ticker) 
    price_list.append(df)
# Out:
# TJX
# LULU
# ROST
# BURL
# RL
# GPS
# LEVI
# TPR
# ZUMZ
# CPRI
# FL
# CRI
# AEO
# URBN
# BKE
# GES
# ANF

# %%
pd.concat(price_list)[['ticker','alpha_5_day','epssurprisepct']].groupby('ticker').describe().reset_index().sort_values([('alpha_5_day','mean')],ascending=False)
# Out:
#    ticker alpha_5_day                                        epssurprisepct  \
#                 count  mean  std   min   25%   50%  75%  max          count
# 7     GES       49.00  0.03 0.19 -0.22 -0.08  0.01 0.08 1.04          53.00
# 0     AEO       49.00  0.01 0.06 -0.12 -0.02  0.02 0.04 0.19          53.00
# 6      FL       49.00  0.01 0.06 -0.17 -0.02  0.01 0.04 0.19          53.00
# 10   LULU       49.00  0.01 0.08 -0.25 -0.05  0.01 0.07 0.15          53.00
# 2     BKE       49.00  0.01 0.05 -0.07 -0.03  0.01 0.03 0.15          53.00
# 12   ROST       49.00  0.01 0.05 -0.08 -0.02  0.01 0.03 0.14          53.00
# 1     ANF       49.00  0.00 0.07 -0.12 -0.05  0.01 0.05 0.20          53.00
# 3    BURL       30.00  0.00 0.04 -0.07 -0.01  0.01 0.02 0.09          34.00
# 14    TPR       49.00  0.00 0.04 -0.08 -0.02  0.00 0.03 0.11          53.00
# 4    CPRI       37.00  0.00 0.05 -0.10 -0.02 -0.00 0.04 0.10          41.00
# 16   ZUMZ       49.00  0.00 0.11 -0.28 -0.06 -0.01 0.06 0.28          53.00
# 13    TJX       49.00  0.00 0.03 -0.07 -0.01  0.01 0.02 0.07          53.00
# 5     CRI       50.00 -0.00 0.04 -0.14 -0.02 -0.00 0.03 0.08          53.00
# 15   URBN       49.00 -0.00 0.10 -0.22 -0.07  0.01 0.08 0.19          53.00
# 11     RL       49.00 -0.00 0.04 -0.09 -0.03 -0.00 0.02 0.09          53.00
# 9    LEVI        8.00 -0.00 0.08 -0.13 -0.03  0.01 0.04 0.08          11.00
# 8     GPS       49.00 -0.02 0.08 -0.25 -0.05  0.00 0.03 0.10          53.00
#
#
#      mean     std      min   25%   50%   75%      max
# 7   45.00  146.82   -87.56 -0.32 13.56 36.74  1037.25
# 0   94.64  477.52  -182.83  0.00  2.63  9.09  2900.00
# 6   12.55   42.86  -169.08  2.47  7.14 16.98   119.03
# 10  12.30   12.51    -6.17  4.31  7.99 15.68    44.02
# 2   10.86  216.04  -988.89 -2.59  3.00  6.49  1190.91
# 12 -47.10  400.89 -2906.45  0.10  1.99  6.00   122.56
# 1  318.69 2099.23  -137.03 -0.28 10.15 47.19 15300.00
# 3   19.26   57.16  -207.49  4.37 13.17 32.11   213.56
# 14   8.21   30.90  -134.78  1.83  4.43 11.56   156.64
# 4  123.72  443.51   -24.14  5.56 15.35 39.53  2095.12
# 16  81.22  358.66   -55.84  5.59 15.05 31.37  2610.53
# 13  -2.88   47.35  -315.73  0.00  2.02  4.22    79.29
# 5   29.03  109.94  -431.97  4.02 11.22 25.42   526.58
# 15   3.60   80.09  -487.50 -1.90  5.17 11.66   208.57
# 11  21.05   36.16   -69.15  6.43 10.32 22.11   160.23
# 9   42.99   51.76     2.44 12.29 28.00 35.77   152.75
# 8   20.84  146.86  -272.96  0.53  2.76  5.02  1023.08

# %% [markdown]
# ### Calculate Earnings Sharpe Ratio, or alpha adjusted return per unit of risk in the 5 day period after earnings

# %%
df = pd.concat(price_list)[['ticker','alpha_5_day']].groupby('ticker').describe().reset_index().sort_values([('alpha_5_day','mean')],ascending=False)
df['earnings_sharpe_ratio'] = df[('alpha_5_day','mean')]/df[('alpha_5_day','std')]
df = df.sort_values([('earnings_sharpe_ratio')],ascending=False)
df['ticker'] = df['ticker']+" US"
df = df.set_axis([f"{x}{y}" for x, y in df.columns], axis=1, inplace=False)[['ticker','earnings_sharpe_ratio']]
df
# Out:
#      ticker  earnings_sharpe_ratio
# 6     FL US                   0.24
# 0    AEO US                   0.23
# 2    BKE US                   0.16
# 12  ROST US                   0.16
# 7    GES US                   0.15
# 3   BURL US                   0.12
# 14   TPR US                   0.09
# 10  LULU US                   0.09
# 13   TJX US                   0.08
# 4   CPRI US                   0.07
# 1    ANF US                   0.06
# 16  ZUMZ US                   0.03
# 5    CRI US                  -0.01
# 15  URBN US                  -0.03
# 9   LEVI US                  -0.04
# 11    RL US                  -0.09
# 8    GPS US                  -0.26

# %% [markdown]
# ### Create a modelset of our stock list

# %%
target_modelset = cd.ModelSet(ticker_list = target_list, config=config,allow_nulls=True)

# %%
#filter out stuff like EPS and StockPrice and FX
feature_list = target_modelset.common_time_series_names()
feature_list = [item for item in feature_list if 'EPS' not in item]
feature_list = [item for item in feature_list if 'StockPrice' not in item]
feature_list = [item for item in feature_list if 'FX' not in item]

# %% [markdown]
# ### Create a model_frame (Pandas dataframe) of common names

# %%
df_target = target_modelset.model_frame(time_series_name=feature_list,
                                        period_duration_type='fiscal_quarter')

# %% [markdown]
# ### Create a featureset of model frame and target vector

# %%
df_featureset = df_target.pivot(index = ['ticker','period_name'],columns = 'time_series_name',values = 'value')
df_featureset = df_featureset.fillna(0).reset_index()
df_featureset = pd.merge(df_featureset,df,how='inner',left_on='ticker',right_on='ticker')
cols = list(df_featureset.columns)
cols.remove('ticker')
cols.remove('period_name')
df_featureset_r = df_featureset[cols]
df_featureset_r['earnings_sharpe_ratio'] = df_featureset_r['earnings_sharpe_ratio'].astype(float)
cols.remove("earnings_sharpe_ratio")
df_featureset_r.head()
# Out:
#    MO_BSS_Cash  MO_BSS_Debt  MO_BSS_Debt_LT  MO_BSS_Debt_Net  MO_BSS_Debt_ST  \
# 0 496216000.00         0.00            0.00    -496216000.00            0.00
# 1 327699000.00         0.00            0.00    -327699000.00            0.00
# 2 326907000.00         0.00            0.00    -326907000.00            0.00
# 3 238976000.00         0.00            0.00    -238976000.00            0.00
# 4 225197000.00         0.00            0.00    -225197000.00            0.00
#
#    MO_BSS_Debt_ToCF  MO_BSS_Debt_ToEBITDA  MO_BSS_IE  MO_BSS_IE_Net  \
# 0              0.00                  0.00       0.00           0.00
# 1              0.00                  0.00       0.00           0.00
# 2              0.00                  0.00       0.00           0.00
# 3              0.00                  0.00       0.00           0.00
# 4              0.00                  0.00       0.00           0.00
#
#    MO_BSS_II  ...  MO_VA_EVCalc_NCI  MO_VA_EVCalc_Other  MO_VA_EVCalc_Prefs  \
# 0       0.00  ...              0.00                0.00                0.00
# 1       0.00  ...              0.00                0.00                0.00
# 2       0.00  ...              0.00                0.00                0.00
# 3       0.00  ...              0.00                0.00                0.00
# 4       0.00  ...              0.00                0.00                0.00
#
#    MO_VA_EV_ToEBITDA  MO_VA_FCFYield_ToEV  MO_VA_FCFYield_ToMktCap  \
# 0               0.00                 0.00                     0.00
# 1               0.00                 0.00                     0.00
# 2               0.00                 0.00                     0.00
# 3               0.00                 0.00                     0.00
# 4               0.00                 0.00                     0.00
#
#    MO_VA_MarketCap  MO_VA_P_ToCF  MO_VA_P_ToE  earnings_sharpe_ratio
# 0    4025833870.00          0.00         0.00                   0.23
# 1    2511655800.00          0.00         0.00                   0.23
# 2    3120368400.00          0.00         0.00                   0.23
# 3    3051222360.00          0.00         0.00                   0.23
# 4    2627972270.00          0.00         0.00                   0.23
#
# [5 rows x 116 columns]

# %% [markdown]
# ### Run multivariate regression and view fit

# %%
import statsmodels.formula.api as smf
formula_string = "+".join(cols)
formula_string = "earnings_sharpe_ratio ~ "+formula_string
mod = smf.ols(formula=formula_string, data=df_featureset_r)
res = mod.fit()
res.summary().tables[0]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ### Display rank ordered coefficients

# %%
pd.set_option('display.max_rows', None)
df_out = pd.DataFrame(res.params).reset_index()
df_out.columns = ['time_series_name','Coefficient']
df_out = df_out.sort_values('Coefficient',ascending = False)
pd.merge(df_out,df_target[['time_series_name','time_series_description']],how='inner',left_on='time_series_name',right_on='time_series_name').groupby('time_series_name').first().reset_index().sort_values('Coefficient',ascending=False)
# Out:
#                                   time_series_name  Coefficient  \
# 74                       MO_KPI_FranchiseStorePerc         0.01
# 50                                    MO_CFSum_DPS         0.01
# 91                                        MO_MA_GM         0.00
# 90                                      MO_MA_COGS         0.00
# 78                             MO_KPI_NetNewStores         0.00
# 86                      MO_KPI_Stores_CompanyOwned         0.00
# 59                        MO_CFSum_NetShares_Price         0.00
# 13                     MO_BSS_NetInterestRate_Debt         0.00
# 75                          MO_KPI_InventorySpread         0.00
# 65                                      MO_KPI_DIO         0.00
# 11                        MO_BSS_InterestRate_Debt         0.00
# 66                                      MO_KPI_DPO         0.00
# 31                             MO_CCFS_Balance_End         0.00
# 64                                      MO_KPI_CCC         0.00
# 93                MO_RIS_Adjustments_Dilution_GAAP         0.00
# 38                              MO_CFS_Balance_End         0.00
# 92                             MO_OS_EmployeeCount         0.00
# 97                            MO_RIS_NI_GAAP_Basic         0.00
# 81                        MO_KPI_OperatingLeverage         0.00
# 7                                        MO_BSS_IE         0.00
# 103                          MO_RIS_ShareCount_WAD         0.00
# 9                                        MO_BSS_II         0.00
# 1                                      MO_BSS_Debt         0.00
# 14                                       MO_BSS_OL         0.00
# 20                                       MO_BS_NCI         0.00
# 106                               MO_VA_EVCalc_NCI         0.00
# 19                                       MO_BS_NCA         0.00
# 43                             MO_CFS_CFO_BeforeWC         0.00
# 29                                      MO_BS_TLSE         0.00
# 27                                        MO_BS_TA         0.00
# 16                                        MO_BS_CA         0.00
# 39                                  MO_CFS_Buyback         0.00
# 44                                       MO_CFS_NI         0.00
# 53                      MO_CFSum_FCF_PostDivPostAD         0.00
# 15                                        MO_BS_AP         0.00
# 68                               MO_KPI_EBITDA_LTM         0.00
# 18                                       MO_BS_INV         0.00
# 94                                     MO_RIS_COGS         0.00
# 21                                       MO_BS_NCL         0.00
# 17                                        MO_BS_CL         0.00
# 101                                     MO_RIS_SBC         0.00
# 73                            MO_KPI_FixedCost_LTM         0.00
# 107                             MO_VA_EVCalc_Other         0.00
# 89                         MO_KPI_VariableCost_LTM         0.00
# 105                                       MO_VA_EV         0.00
# 35                            MO_CCFS_CFO_BeforeWC         0.00
# 77                        MO_KPI_LTMSales_PerStore         0.00
# 62                                  MO_IS_FirstRow         0.00
# 57                        MO_CFSum_NetDebtIssuance         0.00
# 54   MO_CFSum_FCF_PostDivPostADPostDebtPostBuyback         0.00
# 99                       MO_RIS_NI_NONGAAP_Diluted         0.00
# 72                                MO_KPI_FixedCost         0.00
# 108                             MO_VA_EVCalc_Prefs         0.00
# 109                              MO_VA_EV_ToEBITDA         0.00
# 110                            MO_VA_FCFYield_ToEV         0.00
# 111                        MO_VA_FCFYield_ToMktCap         0.00
# 113                                   MO_VA_P_ToCF         0.00
# 114                                    MO_VA_P_ToE         0.00
# 70                            MO_KPI_EmployeeCount        -0.00
# 83                   MO_KPI_Sales_CompanyOwned_LTM        -0.00
# 24                                       MO_BS_PPE        -0.00
# 25                          MO_BS_RetainedEarnings        -0.00
# 63                               MO_IS_NI_ContinOp        -0.00
# 71                                  MO_KPI_FCF_LTM        -0.00
# 32                                     MO_CCFS_CFF        -0.00
# 112                                MO_VA_MarketCap        -0.00
# 61                                       MO_IS_EBT        -0.00
# 49                                  MO_CFSum_Capex        -0.00
# 84                                MO_KPI_Sales_LTM        -0.00
# 100                                     MO_RIS_REV        -0.00
# 96                               MO_RIS_EBITDA_Adj        -0.00
# 33                                     MO_CCFS_CFI        -0.00
# 34                                     MO_CCFS_CFO        -0.00
# 51                            MO_CFSum_Divestiture        -0.00
# 88                             MO_KPI_VariableCost        -0.00
# 69                                 MO_KPI_EBIT_LTM        -0.00
# 22                                       MO_BS_OCI        -0.00
# 23                                MO_BS_OL_Current        -0.00
# 55                       MO_CFSum_FCF_PostDivPreAD        -0.00
# 46                            MO_CFSum_Acquisition        -0.00
# 56                             MO_CFSum_FCF_PreDiv        -0.00
# 47                           MO_CFSum_CFO_BeforeWC        -0.00
# 42                                      MO_CFS_CFO        -0.00
# 58                              MO_CFSum_NetShares        -0.00
# 41                                      MO_CFS_CFI        -0.00
# 40                                      MO_CFS_CFF        -0.00
# 5                                 MO_BSS_Debt_ToCF        -0.00
# 52                               MO_CFSum_Dividend        -0.00
# 6                             MO_BSS_Debt_ToEBITDA        -0.00
# 26                                        MO_BS_SE        -0.00
# 0                                      MO_BSS_Cash        -0.00
# 3                                  MO_BSS_Debt_Net        -0.00
# 28                                        MO_BS_TL        -0.00
# 104                      MO_RIS_ShareCount_WAD_Adj        -0.00
# 76                     MO_KPI_LTMSales_PerEmployee        -0.00
# 4                                   MO_BSS_Debt_ST        -0.00
# 2                                   MO_BSS_Debt_LT        -0.00
# 8                                    MO_BSS_IE_Net        -0.00
# 95                                       MO_RIS_DA        -0.00
# 102                          MO_RIS_ShareCount_WAB        -0.00
# 98                          MO_RIS_NI_GAAP_Diluted        -0.00
# 45                                MO_CFS_NetChange        -0.00
# 37                            MO_CFS_Balance_Begin        -0.00
# 12                      MO_BSS_NetInterestCoverage        -0.00
# 36                               MO_CCFS_NetChange        -0.00
# 30                           MO_CCFS_Balance_Begin        -0.00
# 87                        MO_KPI_Stores_Franchised        -0.00
# 60                              MO_GA_TotalRevenue        -0.00
# 10                        MO_BSS_InterestRate_Cash        -0.00
# 82                               MO_KPI_SSS_Growth        -0.00
# 85                                   MO_KPI_Stores        -0.00
# 48                                   MO_CFSum_CFPS        -0.00
# 79                MO_KPI_NetNewStores_CompanyOwned        -0.00
# 80                  MO_KPI_NetNewStores_Franchised        -0.00
# 67                                      MO_KPI_DSO        -0.00
#
#                               time_series_description
# 74                    Percentage Franchised stores, %
# 50                                 Dividend Per Share
# 91                    Gross Margin (Excluding D&A), %
# 90                     COGS Margin (Excluding D&A), %
# 78                        Net New Stores, # of stores
# 86            Total Company Owned Stores, # of stores
# 59   Estimated Share Price for Issuance/Buybacks, USD
# 13                Effective Net Interest Rate on Debt
# 75                      Sales and Inventory Spread, %
# 65              Days Inventory Outstanding, # of days
# 11                    Effective Interest Rate on Debt
# 66                Days Payable Outstanding, # of days
# 31                                Ending Cash Balance
# 64                   Cash Conversion Cycle, # of days
# 93             Adjustments for Convertible Securities
# 38                                Ending Cash Balance
# 92                     Employee Count, # of employees
# 97                  Net Income to Common Shareholders
# 81                              Operating Leverage, x
# 7                                    Interest Expense
# 103                          Shares Outstanding - WAD
# 9                                     Interest Income
# 1                                                Debt
# 14                        Operating Lease Liabilities
# 20                                                NCI
# 106                           Noncontrolling Interest
# 19                           Total Non-Current Assets
# 43                                      CFO before WC
# 29                             Total Liabilities & SE
# 27                                       Total Assets
# 16                               Total Current Assets
# 39                         Purchase of treasury stock
# 44                                Net earnings (loss)
# 53                             FCF, Post Div Post A/D
# 15                                   Accounts payable
# 68                                     LTM EBITDA, mm
# 18                                        Inventories
# 94                                COGS (adj. for D&A)
# 21                      Total Non-Current liabilities
# 17                          Total Current Liabilities
# 101                                               SBC
# 73                                 LTM Fixed Cost, mm
# 107                               Other EV Components
# 89                             LTM Variable Cost,  mm
# 105                            Enterprise Value - Avg
# 35                                      CFO before WC
# 77                      LTM Sales Per Store, k$/store
# 62                                      Product sales
# 57                      Net Debt Issuance (Repayment)
# 54                  FCF, Post Div, Debt, Buyback, A/D
# 99                                Adjusted Net Income
# 72                                     Fixed Cost, mm
# 108                                  Preferred Shares
# 109                                   EV/EBITDA - Avg
# 110               FCF Yield % to Avg Enterprise Value
# 111                     FCF Yield % to Avg Market Cap
# 113                                        P/CF - Avg
# 114                                         P/E - Avg
# 70                    Total Employees, # of employees
# 83                  LTM Company Owned Store Sales, mm
# 24                        Property and equipment, net
# 25                                  Retained earnings
# 63                                       Net Earnings
# 71                                        LTM FCF, mm
# 32                                            Net CFF
# 112                                  Market Cap - Avg
# 61                 Earnings before Income Tax Expense
# 49                                              Capex
# 84                                      LTM Sales, mm
# 100                                       Net Revenue
# 96                   Adjusted EBITDA (No Adjustments)
# 33                                            Net CFI
# 34                                            Net CFO
# 51                                        Divestiture
# 88                                  Variable Cost, mm
# 69                                       LTM EBIT, mm
# 22               Accumulated other comprehensive loss
# 23     Current portion of operating lease liabilities
# 55                              FCF, Post Div Pre A/D
# 46                                       Acquisitions
# 56                                       FCF, Pre Div
# 47                      Operating Cash Flow before WC
# 42                                            Net CFO
# 58                      Net Share Issuance (Buybacks)
# 41                                            Net CFI
# 40                                            Net CFF
# 5                                Net Debt / Cash Flow
# 52                                      Dividend Paid
# 6                                   Net Debt / EBITDA
# 26                                           Total SE
# 0                                                Cash
# 3                                            Net Debt
# 28                                  Total Liabilities
# 104                 Adjusted Shares Outstanding - WAD
# 76                LTM Sales Per Employee, k$/employee
# 4                                             ST Debt
# 2                                             LT Debt
# 8                       Net Interest Expense (Income)
# 95                                                D&A
# 102                          Shares Outstanding - WAB
# 98          Diluted Net Income to Common Shareholders
# 45                         Net Change in Cash Balance
# 37                             Beginning Cash Balance
# 12                      EBITDA / Net Interest Expense
# 36                         Net Change in Cash Balance
# 30                             Beginning Cash Balance
# 87               Total Franchised Stores, # of stores
# 60                            Total Revenue Growth, %
# 10                    Effective Interest Rate on Cash
# 82                         Same Store Sales Growth, %
# 85                     Total Store Count, # of stores
# 48                        Cash Flow Per Diluted Share
# 79          Net New Company Owned Stores, # of stores
# 80             Net New Franchised Stores, # of stores
# 67                  Days Sales Outstanding, # of days
