# %% [markdown]
# # Imports

# %%
from IPython.display import display as dsp
from datetime import datetime as dt
from random import sample


import sys
import os
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.max_colwidth', 400)

import canalyst_candas.candas as cd
from canalyst_candas.configuration.config import Config

config_info = {
  "canalyst_api_key": "",
  "s3_access_key_id": "",
  "s3_secret_key": "",
  "fred_key": "",
  "default_dir": "",
  "mds_host": "",
  "wp_host": ""
}

config = Config(config=config_info)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Creating A Search Object

# %%
# Instantiate new search object:
search = cd.Search(config)

# %% [markdown]
# # Searching for Consumer Companies with Stores

# %%
# A search for "Consumer" companies with exposure to "store":
search_results_df = search.search_time_series(
    sector="Consumer",
    time_series_name="store"
)
# Out:
# Building search index...
# Done

# %%
# There are over 1m rows in the search index:
dsp(search.df_search.shape)
dsp(search.df_search.head())
# Out:
# (1273274, 27)
#    Unnamed: 0 Bloomberg Ticker  \
# 0           0         GOOGL US
# 1           1         GOOGL US
# 2           2         GOOGL US
# 3           3         GOOGL US
# 4           4         GOOGL US
#
#                                                                Path  \
# 0  US Companies/Communication Services/Interactive Media & Services
# 1  US Companies/Communication Services/Interactive Media & Services
# 2  US Companies/Communication Services/Interactive Media & Services
# 3  US Companies/Communication Services/Interactive Media & Services
# 4  US Companies/Communication Services/Interactive Media & Services
#
#                  Filename        CSIN  index    ticker period_name  \
# 0  Alphabet GOOGL US.xlsx  U07N2S0124  21876  GOOGL US     Q3-2021
# 1  Alphabet GOOGL US.xlsx  U07N2S0124  22161  GOOGL US     Q3-2021
# 2  Alphabet GOOGL US.xlsx  U07N2S0124  16632  GOOGL US     Q3-2021
# 3  Alphabet GOOGL US.xlsx  U07N2S0124  18627  GOOGL US     Q3-2021
# 4  Alphabet GOOGL US.xlsx  U07N2S0124  24669  GOOGL US     Q3-2021
#
#   period_duration_type period_start_date  ... unit_description unit_symbol  \
# 0       fiscal_quarter        2021-07-01  ...       Percentage           %
# 1       fiscal_quarter        2021-07-01  ...       Percentage           %
# 2       fiscal_quarter        2021-07-01  ...       Percentage           %
# 3       fiscal_quarter        2021-07-01  ...       Percentage           %
# 4       fiscal_quarter        2021-07-01  ...       Percentage           %
#
#     unit_type value is_historical category_slug      MRQ is_driver name_index  \
# 0  percentage 44.00          True           NaN  Q3-2021      True       7.00
# 1  percentage 43.04          True           NaN  Q3-2021      True       8.00
# 2  percentage 43.84          True           NaN  Q3-2021     False       9.00
# 3  percentage 39.84          True           NaN  Q3-2021      True      10.00
# 4  percentage 43.23          True           NaN  Q3-2021     False      11.00
#
#   period_name_sorted
# 0             2021Q3
# 1             2021Q3
# 2             2021Q3
# 3             2021Q3
# 4             2021Q3
#
# [5 rows x 27 columns]

# %%
# Common time series:
gpd_search = search_results_df.groupby("time_series_name")[["ticker"]].nunique().reset_index().copy()
gpd_search.sort_values(by="ticker", ascending=False, inplace=True)
gpd_search.head(10)
# Out:
#                   time_series_name  ticker
# 128               MO_OS_Stores_EoP     112
# 125            MO_OS_Stores_Closed      97
# 131               MO_OS_Stores_New      96
# 122               MO_OS_Stores_BoP      96
# 22             MO_OS_AverageStores      79
# 105               MO_OS_SSS_Stores      71
# 67             MO_OS_SSS_NewStores      69
# 81     MO_OS_SSS_SalesPerCompStore      64
# 75   MO_OS_SSS_SalesFromCompStores      63
# 78    MO_OS_SSS_SalesFromNewStores      63

# %%
# Common time series drivers:
driver_df = search_results_df[search_results_df["is_driver"] == True].copy()
gpd_search = driver_df.groupby("time_series_name")[["ticker"]].nunique().copy()
gpd_search.sort_values(by="ticker", ascending=False, inplace=True)
gpd_search.reset_index(inplace=True)
dsp(gpd_search)

# Turn into a list:
most_common_driver = gpd_search["time_series_name"].iloc[0]
dsp(driver_df[driver_df["time_series_name"].str.contains(most_common_driver)].head(10))
dsp(driver_df[driver_df["time_series_name"].str.contains(most_common_driver)].shape)
dsp(driver_df[driver_df["time_series_name"].str.contains(most_common_driver)]["ticker"].nunique())
driver_df[driver_df["time_series_name"].str.contains(most_common_driver)].to_clipboard()
# Out:
#                                                  time_series_name  ticker
# 0                                                MO_OS_Stores_New      60
# 1                                             MO_OS_Stores_Closed      60
# 2                                    MO_OS_SSS_NewStoreEfficiency      54
# 3                                   MO_OS_Stores_New_CompanyOwned      16
# 4                                MO_OS_Stores_Closed_CompanyOwned      15
# ..                                                            ...     ...
# 828                         z_9ZBMO80150_MO_OS_Canadastoresclosed       1
# 829                         z_9ZBMO80150_MO_OS_Canadastoresopened       1
# 830                      z_9ZBMO80150_MO_OS_DSWNewStoreEfficiency       1
# 831                            z_9ZBMO80150_MO_OS_DSWstoresclosed       1
# 832  z_ZUIQ1M0180_MO_GA_CasualDiningYYchangeinsalesperavgofstores       1
#
# [833 rows x 2 columns]
#          ticker        CSIN  \
# 725454  ZUMZ US  8X9RM80141
# 577115   WMK US  WIF7CE0146
# 74896   WING US  HUWCDD0172
# 554482   VRA US  MBCNOK0167
# 85569   ULTA US  EYUO400147
# 713080  TLYS US  O6EOCO0152
# 64715    TGT US  A1RO3K0126
# 568395   TCS US  K0FA000179
# 744217  TACO US  N44XEU0149
# 744182  TACO US  N44XEU0149
#
#                                                                                     Path  \
# 725454  US Companies/Consumer Discretionary/Apparel, Accessories & Luxury/Apparel Retail
# 577115        US Companies/Consumer Staples/Food & Beverage/Hypermarkets & Super Centers
# 74896                      US Companies/Consumer Discretionary/Restaurants/Casual Dining
# 554482     US Companies/Consumer Discretionary/Apparel, Accessories & Luxury/Accessories
# 85569                      US Companies/Consumer Staples/Personal Products/Beauty Retail
# 713080  US Companies/Consumer Discretionary/Apparel, Accessories & Luxury/Apparel Retail
# 64715      US Companies/Consumer Discretionary/Staples Retail/General Merchandise Stores
# 568395                              US Companies/Consumer Discretionary/Specialty Stores
# 744217          US Companies/Consumer Discretionary/Restaurants/Quick Service Restaurant
# 744182          US Companies/Consumer Discretionary/Restaurants/Quick Service Restaurant
#
#                            Filename  \
# 725454          Zumiez ZUMZ US.xlsx
# 577115     Weis Markets WMK US.xlsx
# 74896         Wingstop WING US.xlsx
# 554482     Vera Bradley VRA US.xlsx
# 85569      Ulta Beauty ULTA US.xlsx
# 713080          Tillys TLYS US.xlsx
# 64715            Target TGT US.xlsx
# 568395  Container Store TCS US.xlsx
# 744217        Del Taco TACO US.xlsx
# 744182        Del Taco TACO US.xlsx
#
#                                                     category  \
# 725454                 Operating Stats - Store Analysis (FS)
# 577115       Operating Stats - Revenue per Retail Store (FS)
# 74896               Operating Stats - Company-Owned Analysis
# 554482     Operating Stats - VB Direct Store Analysis (MD&A)
# 85569                  Operating Stats - Same Store Analysis
# 713080              Operating Stats - Retail Stores SSS (PR)
# 64715                           Operating Stats - Store Data
# 568395           Operating Stats - TCS Store Analysis (MD&A)
# 744217        Operating Stats - Store Franchised Stores (PR)
# 744182  Operating Stats - Store Company-operated Stores (PR)
#
#                                                 time_series_description  \
# 725454                                       Stores opened, # of stores
# 577115                     Additions of supermarket stores, # of stores
# 74896   Domestic company-owned openings during period, # of restaurants
# 554482                              VB Direct Store opened, # of stores
# 85569                                         Store opened, # of stores
# 713080                                       Opened stores, # of stores
# 64715                                        Stores Opened, # of stores
# 568395                                            Openings, # of stores
# 744217               Franchised restaurants additions, # of restaurants
# 744182            Company-operated restaurants opened, # of restaurants
#
#                      time_series_name period_duration_type unit_type  \
# 725454               MO_OS_Stores_New       fiscal_quarter     count
# 577115               MO_OS_Stores_New       fiscal_quarter     count
# 74896   MO_OS_Stores_New_CompanyOwned       fiscal_quarter     count
# 554482               MO_OS_Stores_New       fiscal_quarter     count
# 85569                MO_OS_Stores_New       fiscal_quarter     count
# 713080               MO_OS_Stores_New       fiscal_quarter     count
# 64715                MO_OS_Stores_New       fiscal_quarter     count
# 568395               MO_OS_Stores_New       fiscal_quarter     count
# 744217    MO_OS_Stores_New_Franchised       fiscal_quarter     count
# 744182  MO_OS_Stores_New_CompanyOwned       fiscal_quarter     count
#
#         is_driver  value  search_matches
# 725454       True   3.00               1
# 577115       True   0.00               1
# 74896        True   1.00               1
# 554482       True   3.00               1
# 85569        True   7.00               1
# 713080       True   6.00               1
# 64715        True   2.00               1
# 568395       True   0.00               1
# 744217       True   3.00               1
# 744182       True   1.00               1
# (87, 12)
# 77

# %%
# A list of tickers for this driver:
ts = gpd_search["time_series_name"].iloc[0]
store_tickers = list(driver_df[driver_df["time_series_name"] == ts]["ticker"].unique())
len(store_tickers)
# Out:
# 60

# %% [markdown]
# # Create a Model Set of "Store Companies"

# %%
# Create a model set form this ticker list:
start = dt.now()
store_set = cd.ModelSet(ticker_list=store_tickers[0:4], config=config, allow_nulls=True)

# Tkaes around 5 minutes:
dsp((dt.now() - start).seconds)
# Out:
# 10

# %%
start = dt.now()
# Create params:
df_params = store_set.forecast_frame(ts,
                             n_periods=range(0,4),
                             function_name='multiply',
                             function_value=1.1)
# Tkaes around 5 minutes:
dsp((dt.now() - start).seconds)
dsp(df_params.shape)
dsp(df_params.head())
# Out:
# 0
# (16, 6)
#        ticker period_name  time_series_name  value  new_value period_end_date
# 636   ULTA US     Q3-2021  MO_OS_Stores_New  10.00      11.00      2021-10-30
# 2484   VRA US     Q3-2022  MO_OS_Stores_New   2.00       2.20      2021-10-30
# 5656  ZUMZ US     Q3-2021  MO_OS_Stores_New  11.00      12.10      2021-10-30
# 4292   WMK US     Q4-2021  MO_OS_Stores_New   1.00       1.10      2022-01-01
# 637   ULTA US     Q4-2021  MO_OS_Stores_New  10.00      11.00      2022-01-29

# %%
# Pick a sample of just 4:
sample_tickers = sample(list(df_params["ticker"].unique()), 4)
sample_params = df_params[df_params["ticker"].isin(sample_tickers)].copy()
sample_params.shape
# Out:
# (16, 6)

# %% [markdown]
# # Run Scenarios on Common Time Series

# %%
start = dt.now()

# How much does revenue move?
return_series = "MO_RIS_REV"

# Scenarios for a sample of 10:
dicts_output=store_set.fit(sample_params,return_series)

# Print time:
dsp((dt.now() - start).seconds)
# Out:
# VRA US scenario_id_url: https://mds.canalyst.com/api/equity-model-series/MBCNOK0167/equity-models/Q2-2022.25/scenarios/uQNew4G0UkmGs7ujZXgD6g/
# ZUMZ US scenario_id_url: https://mds.canalyst.com/api/equity-model-series/EYUO400147/equity-models/Q2-2021.20/scenarios/Bs8ZJ2I9X76pcOBqr7bKFg/
# WMK US scenario_id_url: https://mds.canalyst.com/api/equity-model-series/WIF7CE0146/equity-models/Q3-2021.22/scenarios/qXZdr4ZwXtGsWpKj-XyiIQ/
# ULTA US scenario_id_url: https://mds.canalyst.com/api/equity-model-series/EYUO400147/equity-models/Q2-2021.20/scenarios/Bs8ZJ2I9X76pcOBqr7bKFg/
# 22

# %%
# Show scenario results:
for k in dicts_output.keys():
    dsp(dicts_output[k])
# Out:
#    ticker period_name time_series_name time_series_description  \
# 0  VRA US     Q3-2022       MO_RIS_REV             Net Revenue
# 1  VRA US     Q4-2022       MO_RIS_REV             Net Revenue
# 2  VRA US     Q1-2023       MO_RIS_REV             Net Revenue
# 3  VRA US     Q2-2023       MO_RIS_REV             Net Revenue
# 4  VRA US     Q3-2023       MO_RIS_REV             Net Revenue
# 5  VRA US     Q4-2023       MO_RIS_REV             Net Revenue
#
#           default        scenario    diff
# 0 139182978.27880   139277616.078 1.00068
# 1 162909232.50469   163138349.341 1.00141
# 2 119715061.13654  119964496.3692 1.00208
# 3 152827048.49435   153282482.943 1.00298
# 4 143882456.95239  144277659.2222 1.00275
# 5 168824296.35373  169295989.0952 1.00279
#     ticker period_name time_series_name time_series_description  \
# 0  ZUMZ US     Q3-2021       MO_RIS_REV             Net Revenue
# 1  ZUMZ US     Q4-2021       MO_RIS_REV             Net Revenue
# 2  ZUMZ US     Q1-2022       MO_RIS_REV             Net Revenue
# 3  ZUMZ US     Q2-2022       MO_RIS_REV             Net Revenue
# 4  ZUMZ US     Q3-2022       MO_RIS_REV             Net Revenue
# 5  ZUMZ US     Q4-2022       MO_RIS_REV             Net Revenue
#
#           default         scenario    diff
# 0 298066315.32429   1656504440.615 5.55750
# 1 348585942.20036  2343567993.6454 6.72307
# 2 239776171.09798  2054032312.6595 8.56646
# 3 274153717.65139  2060193658.7309 7.51474
# 4 302658327.94702  1792487817.6027 5.92248
# 5 352499702.25677  2557885780.8133 7.25642
#    ticker period_name time_series_name time_series_description  \
# 0  WMK US     Q4-2021       MO_RIS_REV             Net Revenue
# 1  WMK US     Q1-2022       MO_RIS_REV             Net Revenue
# 2  WMK US     Q2-2022       MO_RIS_REV             Net Revenue
# 3  WMK US     Q3-2022       MO_RIS_REV             Net Revenue
# 4  WMK US     Q4-2022       MO_RIS_REV             Net Revenue
#
#            default         scenario    diff
# 0 1121752561.05363   1122066946.457 1.00028
# 1 1029631418.04974  1029946933.2953 1.00031
# 2 1065246174.03327   1065571274.595 1.00031
# 3 1084842026.86126  1085173107.8461 1.00031
# 4 1044464154.52257  1045135184.4062 1.00064
#     ticker period_name time_series_name time_series_description  \
# 0  ULTA US     Q3-2021       MO_RIS_REV             Net Revenue
# 1  ULTA US     Q4-2021       MO_RIS_REV             Net Revenue
# 2  ULTA US     Q1-2022       MO_RIS_REV             Net Revenue
# 3  ULTA US     Q2-2022       MO_RIS_REV             Net Revenue
# 4  ULTA US     Q3-2022       MO_RIS_REV             Net Revenue
# 5  ULTA US     Q4-2022       MO_RIS_REV             Net Revenue
#
#            default         scenario    diff
# 0 1655248489.39422   1656504440.615 1.00076
# 1 2340020561.59407  2343567993.6454 1.00152
# 2 2049998158.25329  2054032312.6595 1.00197
# 3 2054200529.81889  2060193658.7309 1.00292
# 4 1786882011.44315  1792487817.6027 1.00314
# 5 2549313836.95305  2557885780.8133 1.00336
