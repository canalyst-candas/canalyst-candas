# %%
import sys
import os
import dtale
import dtale.app as dtale_app
dtale_app.JUPYTER_SERVER_PROXY = True
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.5f' % x)
import canalyst_candas.candas as cd
import canalyst_candas.candas_datareader as cdr
from canalyst_candas.configuration.config import Config
config_info = {
  "canalyst_api_key": "",
  "s3_access_key_id": "",
  "s3_secret_key": "",
  "fred_key": "",
  "default_dir": "",
  "mds_host": "",
  "wp_host": ""
}
config = Config(config=config_info)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)
# Out:
# A configuration file has been created for you in
# /home/canalyst_candas/canalyst/keys.json. For Excel file downloads and scenario
# mapping, you'll need to add an API key to the 'canalyst_api_key'
# value. Visit https://app.canalyst.com/settings/api-tokens to create
# and retrieve your API key. You will also need to retrieve your
# S3 Access ID and Secret Key and fill in 'canalyst_s3_id' and
# 'canalyst_s3_key' with those values, respectively. If using a
# Jupyter Notebook, stop and restart the notebook for the changes to
# take effect. If using a Python/iPython session, quit the current
# session and start a new one.
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## JPM Read Through for consumer credit costs to DFS and COF

# %% [markdown]
# ### First we search for common time series among JPM V and MA with 'credit card sales volume debit payments US'

# %%
canalyst_search = cd.Search(config)
df = canalyst_search.search_time_series(ticker=['JPM US','COF US','DFS US'],
                                        unit_type='currency',
                     time_series_description='credit card consumer credit charge-off recoveries')[['ticker','time_series_description','time_series_name','search_matches']]
df= df[df['search_matches']>1]
# Out:
# Building search index...
# No.of.unique tickers:  3
# No.of.unique time series:  131

# %%
df
#these are our three series
#JPM US z_3FRM7X0148_MO_OS_netchargeoffsrecoveries
#COF US z_YN5MQC0170_MO_OS_CreditCardNetchargeoffs	
#DF US z_YDE7B00120_MO_OS_netchargeoffs
# Out:
#         ticker                                                  time_series_description                                                              time_series_name  search_matches
# 502605  COF US  Credit Card - Domestic credit card, mm                                   z_YN5MQC0170_MO_OS_CreditCardDomesticcreditcard                               4
# 502539  COF US  Credit Card - Provision for credit losses, mm                            z_YN5MQC0170_MO_OS_CreditCardProvisionforcreditlosses                         3
# 502547  COF US  Credit Card - Net charge-offs, mm                                        z_YN5MQC0170_MO_OS_CreditCardNetchargeoffs                                    3
# 502606  COF US  Credit Card - International card businesses, mm                          z_YN5MQC0170_MO_OS_CreditCardInternationalcardbusinesses                      3
# 50232   JPM US  Net Charge-offs/(recoveries), mm                                         z_3FRM7X0148_MO_OS_netchargeoffsrecoveries                                    2
# 50289   JPM US  Debit and credit card sales volumes, bn                                  z_3FRM7X0148_MO_OS_Debitandcreditcardsalesvolumes                             2
# 50223   JPM US  Cumulative Net Charge-offs/(recoveries), mm                              z_3FRM7X0148_MO_OS_cumulativenetchargeoffsrecoveries                          2
# 50448   JPM US  Credit card securitization adjustment                                    z_3FRM7X0148_MO_OS_Creditcardsecuritizationadjustment                         2
# 50287   JPM US  Credit card sales volume, bn                                             z_3FRM7X0148_MO_OS_Creditcardsalesvolume                                      2
# 50267   JPM US  Consumer & Community Banking Provision for credit losses, mm             z_3FRM7X0148_MO_OS_ConsumerCommunityBankingProvisionforcreditlosses           2
# 50262   JPM US  Consumer & Community Banking Card Income, mm                             z_3FRM7X0148_MO_OS_ConsumerCommunityBankingCardIncome                         2
# 440721  DFS US  Credit card loans income, mm                                             z_YDE7B00120_MO_OS_Creditcardloansincome_1                                    2
# 440733  DFS US  Credit card loans income, mm                                             z_YDE7B00120_MO_OS_Creditcardloansincome_2                                    2
# 440658  DFS US  Credit card loans - avg. balance, mm                                     z_YDE7B00120_MO_OS_creditcardloansavgbalance                                  2
# 440758  DFS US  Credit card loans                                                        MO_IS_FirstRow                                                                2
# 440836  DFS US  Credit card loans                                                        MO_BSS_creditcardloans                                                        2
# 440676  DFS US  Credit card loan income, mm                                              z_YDE7B00120_MO_OS_creditcardloanincome                                       2
# 502562  COF US  Total domestic credit card, mm                                           z_YN5MQC0170_MO_OS_Totaldomesticcreditcard                                    2
# 502566  COF US  Total credit card, mm                                                    z_YN5MQC0170_MO_OS_Totalcreditcard                                            2
# 502607  COF US  Total credit card, mm                                                    z_YN5MQC0170_MO_OS_Totalcreditcard_1                                          2
# 502552  COF US  Domestic credit card - Texas, mm                                         z_YN5MQC0170_MO_OS_DomesticcreditcardTexas                                    2
# 502555  COF US  Domestic credit card - Pennsylvania, mm                                  z_YN5MQC0170_MO_OS_DomesticcreditcardPennsylvania                             2
# 502561  COF US  Domestic credit card - Other, mm                                         z_YN5MQC0170_MO_OS_DomesticcreditcardOther                                    2
# 502557  COF US  Domestic credit card - Ohio, mm                                          z_YN5MQC0170_MO_OS_DomesticcreditcardOhio                                     2
# 502554  COF US  Domestic credit card - New York, mm                                      z_YN5MQC0170_MO_OS_DomesticcreditcardNewYork                                  2
# 502558  COF US  Domestic credit card - New Jersey, mm                                    z_YN5MQC0170_MO_OS_DomesticcreditcardNewJersey                                2
# 502560  COF US  Domestic credit card - Michigan, mm                                      z_YN5MQC0170_MO_OS_DomesticcreditcardMichigan                                 2
# 502556  COF US  Domestic credit card - Illinois, mm                                      z_YN5MQC0170_MO_OS_DomesticcreditcardIllinois                                 2
# 502559  COF US  Domestic credit card - Georgia, mm                                       z_YN5MQC0170_MO_OS_DomesticcreditcardGeorgia                                  2
# 502553  COF US  Domestic credit card - Florida, mm                                       z_YN5MQC0170_MO_OS_DomesticcreditcardFlorida                                  2
# 502551  COF US  Domestic credit card - California, mm                                    z_YN5MQC0170_MO_OS_DomesticcreditcardCalifornia                               2
# 502481  COF US  Credit cards income, mm                                                  z_YN5MQC0170_MO_OS_creditcardsincome                                          2
# 502465  COF US  Credit cards - avg. balance, mm                                          z_YN5MQC0170_MO_OS_creditcardsavgbalance                                      2
# 502737  COF US  Credit card loans                                                        MO_BSS_creditcardloans                                                        2
# 502538  COF US  Credit Card - Total revenue, mm                                          z_YN5MQC0170_MO_OS_CreditCardTotalrevenue                                     2
# 502549  COF US  Credit Card - Purchase volume, mm                                        z_YN5MQC0170_MO_OS_CreditCardPurchasevolume                                   2
# 502537  COF US  Credit Card - Non-interest income, mm                                    z_YN5MQC0170_MO_OS_CreditCardNoninterestincome                                2
# 502540  COF US  Credit Card - Non-interest expense, mm                                   z_YN5MQC0170_MO_OS_CreditCardNoninterestexpense                               2
# 502536  COF US  Credit Card - Net interest income, mm                                    z_YN5MQC0170_MO_OS_CreditCardNetinterestincome                                2
# 502542  COF US  Credit Card - Income tax provision, mm                                   z_YN5MQC0170_MO_OS_CreditCardIncometaxprovision                               2
# 502543  COF US  Credit Card - Income from continuing operations, net of tax, mm          z_YN5MQC0170_MO_OS_CreditCardIncomefromcontinuingoperationsnetoftax           2
# 502541  COF US  Credit Card - Income from continuing operations before income taxes, mm  z_YN5MQC0170_MO_OS_CreditCardIncomefromcontinuingoperationsbeforeincometaxes  2
# 502544  COF US  Credit Card - Average loans held for investment, mm                      z_YN5MQC0170_MO_OS_CreditCardAverageloansheldforinvestment                    2
# 502570  COF US  Consumer Banking - Provision for credit losses, mm                       z_YN5MQC0170_MO_OS_ConsumerBankingProvisionforcreditlosses                    2
# 502579  COF US  Consumer Banking - Net charge-offs, mm                                   z_YN5MQC0170_MO_OS_ConsumerBankingNetchargeoffs                               2

# %% [markdown]
# ### Now that we have our series, let's pull the data from Canalyst

# %%
ticker = "JPM US"

# %%
model_set = cd.ModelSet(ticker_list=[ticker], 
                            config=config)

# %%
df_jpm_credit = model_set.model_frame(ticker=ticker,
                      period_duration_type='fiscal_quarter',
                      is_historical=True,
                      time_series_name='z_3FRM7X0148_MO_OS_netchargeoffsrecoveries')[['ticker','time_series_name','period_end_date','value']]

# %% [markdown]
# ### Next we get COF data from Canalyst

# %%
ticker = "COF US"
model_set = cd.ModelSet(ticker_list=[ticker], 
                            config=config)
df_cof_credit = model_set.model_frame(ticker=ticker,
                      period_duration_type='fiscal_quarter',
                      time_series_name='z_YN5MQC0170_MO_OS_CreditCardNetchargeoffs')[['ticker','time_series_name','period_end_date','value']]

# %% [markdown]
# ### Same data pull for DFS

# %%
ticker = "DFS US"
model_set = cd.ModelSet(ticker_list=[ticker], 
                            config=config)
df_dfs_credit = model_set.model_frame(ticker=ticker,
                      period_duration_type='fiscal_quarter',
                      time_series_name='z_YDE7B00120_MO_OS_netchargeoffs')[['ticker','time_series_name','period_end_date','value']]

# %% [markdown]
# ### Now we use the regress_dataframe function from Candas DataReader

# %% [markdown]
# #### JPM credit vs COF credit

# %%
df = pd.merge(df_jpm_credit,df_cof_credit,how='inner',left_on='period_end_date',right_on='period_end_date')[['period_end_date','value_x','value_y']]
cdr.regress_dataframe(df,'value_y','value_x',y_filter="").tables[0]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# #### JPM credit vs DFS credit

# %%
df = pd.merge(df_jpm_credit,df_dfs_credit,how='inner',left_on='period_end_date',right_on='period_end_date')[['period_end_date','value_x','value_y']]
cdr.regress_dataframe(df,'value_y','value_x',y_filter="").tables[0]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
